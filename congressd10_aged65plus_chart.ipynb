# %%
import numpy as np
from numpy import sqrt, arange
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy as sci
import pyreadstat
import matplotlib.ticker as mtick
#.special
#.scipy.linalg
#.interpolate
#.integrate
#.signal
#.file
from scipy import stats

import warnings
warnings.filterwarnings('ignore')

ldat = pd.read_csv(r"C:\Users\ithompson\OneDrive - CSSNY\Documents\LESGRN.csv")

# %%
#plt.subplot(totalnumber of rows, total number of columns, plot number) 
plt.figure(figsize = (10,15))
plt.subplot(4, 4, 1)
plt.suptitle('Housing Crisis In Lower Manhattan for 65+ Population', fontsize=16, y=1)


sns.barplot(x='Year', y='mediangrossrent', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('Median Rent')
sns.set_style("dark")
sns.despine(trim=True)

plt.subplot(4,4,2)
sns.barplot(x='Year', y= 'RentBurdenedPercentage', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('Rent Burdened')
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.subplot(4, 4, 3) 
sns.barplot(x='Year', y='RentBurdenedPercentageDifferenceBetweenSeniorsandTotalPop', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('% Diff: Rent-Burdened Total vs 65+ Pop', wrap=True)
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))


plt.subplot(4,4,4)
sns.barplot(x='Year', y= 'OwnerCostBurdenedPercentageDifferenc BetweenSeniorsandTotalPop', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('% Diff: Cost-Burdened Total vs 65+ Pop (Owners)', wrap=True)
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.subplot(4, 4, 5) 
sns.barplot(x='Year', y='Atorabove150percentofthepovertylevel', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('>= 150% of the FPL')
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.subplot(4,4,6)
sns.barplot(x='Year', y= 'InLaborForce', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('In the Labor Force')
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.subplot(4, 4, 7) 
sns.barplot(x='Year', y='OwnerCostBurdenedPercentage', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('Cost Burdened Owner')
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

plt.subplot(4,4,8)
sns.barplot(x='Year', y= 'WithDisability', capsize = .05, edgecolor = '0.2', lw = 2.5, errwidth = 2.5, ci=None, data=ldat,
                 palette = ['#e69f00','#009e73'])
plt.ylabel('% w/ Disability')
sns.set_style("dark")
sns.despine(right=True)
plt.gca().yaxis.set_major_formatter(mtick.PercentFormatter(xmax=1.0))

sns.set_context("paper", font_scale=1, rc={"lines.linewidth": .7})
plt.subplots_adjust(left=0.2, wspace=0.8, top=1)
plt.tight_layout()

plt.savefig('LowerMN_censusdatacharts.png', bbox_inches = 'tight', dpi = 250)
